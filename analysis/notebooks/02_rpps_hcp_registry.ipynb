# %% [markdown]
# # RPPS / ADELI — Démographie des professionnels de santé (DREES)
#
# **Source :** DREES / OSAM — *La démographie des professionnels de santé depuis 2012*
# **Format :** Excel (.xlsx), statistiques agrégées | **Licence :** Licence Ouverte v2.0 (Etalab)
#
# Tableaux statistiques annuels produits par la DREES à partir du RPPS (Répertoire Partagé des Professionnels de Santé), du répertoire ADELI, de la Base Tous Salariés (BTS) et du SNDS. Un fichier par profession, avec des indicateurs déclinés par région, département, genre, tranche d'âge et mode d'exercice.
#
# ## Contexte : RPPS vs ADELI
#
# Le RPPS remplace progressivement ADELI depuis 2012 — ADELI a été **décommissionné en octobre 2024**.
#
# | Année | Professions | Source dans les fichiers DREES |
# |-------|-------------|-------------------------------|
# | 2012 | Médecins, chirurgiens-dentistes, pharmaciens, sages-femmes | RPPS |
# | 2017 | Masseurs-kinésithérapeutes | RPPS (ADELI avant) |
# | 2018 | Pédicures-podologues | RPPS (ADELI avant) |
# | 2022 | Infirmières | RPPS (qualité insuffisante → BTS/SNDS) |
# | Oct. 2024 | Dernières professions | RPPS |
#
# ## Questions couvertes dans ce notebook
#
# | # | Question | Source principale |
# |---|----------|-------------------|
# | Q1 | Effectifs par profession — dernière année disponible | Tous fichiers DREES |
# | Q2 | Répartition des médecins par spécialité | Médecins RPPS 2012-2025 |
# | Q3 | Libéral vs Salarié par profession | Onglet Effectifs, colonne `exercice` |
# | Q4 | Évolution temporelle des effectifs | Colonnes `effectif_YYYY` |
# | Q5 | Disparités géographiques par région | Colonnes `region` + `effectif_YYYY` |

# %%
import pandas as pd
import matplotlib.pyplot as plt
from pathlib import Path

RAW_DIR = Path("../../data/raw/rpps")

# ── Fichiers DREES par profession ─────────────────────────────────────────────
RPPS_FILES = {
    "Médecins":              RAW_DIR / "Médecins RPPS 2012-2025.xlsx",
    "Chirurgiens-dentistes": RAW_DIR / "Chirurgiens-dentistes RPPS 2012-2025.xlsx",
    "Pharmaciens":           RAW_DIR / "Pharmaciens RPPS 2012-2025.xlsx",
    "Sages-femmes":          RAW_DIR / "Sages-femmes RPPS 2012-2025.xlsx",
    "Kinésithérapeutes":     RAW_DIR / "Kinésithérapeutes RPPS 2017-2024.xlsx",
    "Pédicures-podologues":  RAW_DIR / "Pédicures-podologues RPPS 2018-2025.xlsx",
}

ADELI_FILES = {
    "Orthophonistes":              RAW_DIR / "Orthophonistes ADELI 2012-2024.xlsx",
    "Orthoptistes":                RAW_DIR / "Orthoptistes ADELI 2012-2024.xlsx",
    "Opticiens-lunetiers":         RAW_DIR / "Opticiens-lunetiers ADELI 2012-2024.xlsx",
    "Audioprothésistes":           RAW_DIR / "Audioprothésistes ADELI 2012-2024.xlsx",
    "Psychologues":                RAW_DIR / "Psychologues ADELI 2012-2024.xlsx",
    "Psychomotriciens":            RAW_DIR / "Psychomotriciens ADELI 2012-2024.xlsx",
    "Ergothérapeutes":             RAW_DIR / "Ergothérapeutes ADELI 2012-2024.xlsx",
    "Diététiciens":                RAW_DIR / "Diététiciens ADELI 2012-2024.xlsx",
    "Manipulateurs ERM":           RAW_DIR / "Manipulateurs ERM ADELI 2012-2024.xlsx",
    "Techniciens de laboratoire":  RAW_DIR / "Techniciens de laboratoire ADELI 2012-2024.xlsx",
    "Professionnels appareillage": RAW_DIR / "Professionnels de l'appareillage ADELI 2012-2024.xlsx",
}

OTHER_FILES = {
    "Infirmières salariées":  RAW_DIR / "Infirmières salariées BTS 2013-2021.xlsx",
    "Infirmières libérales":  RAW_DIR / "Infirmières libérales SNDS 2012-2023.xlsx",
    "Aides-soignantes":       RAW_DIR / "Aides-soignantes BTS 2013-2021.xlsx",
}

ALL_FILES = {**RPPS_FILES, **ADELI_FILES, **OTHER_FILES}


def load_effectifs(path: Path, sheet: str = "Effectifs") -> pd.DataFrame:
    """Load an Effectifs sheet, normalising column names."""
    df = pd.read_excel(path, sheet_name=sheet, header=0)
    df.columns = [str(c).strip() for c in df.columns]
    return df


def effectif_cols(df: pd.DataFrame) -> list[str]:
    """Return sorted list of effectif_YYYY columns present in df."""
    return sorted(c for c in df.columns if c.startswith("effectif_"))


def total_row(df: pd.DataFrame) -> pd.Series:
    """Return the national Ensemble row (France entière, all dims = Ensemble/0-Ensemble)."""
    mask = pd.Series(True, index=df.index)
    for col in df.columns:
        cl = col.lower()
        if "territoire" in cl:
            mask &= df[col].astype(str).str.contains("France", na=False)
        elif "tranche" in cl or ("age" in cl and "am_" not in cl):
            mask &= df[col].astype(str).str.match(r"^0", na=False)
        elif "sexe" in cl:
            mask &= df[col].astype(str).str.match(r"^0", na=False)
        elif "exercice" in cl:
            mask &= df[col].astype(str).str.match(r"^0", na=False)
        elif "specialite" in cl:
            mask &= df[col].astype(str).str.match(r"^0", na=False)
        elif "secteur" in cl:
            mask &= df[col].astype(str).str.match(r"^0", na=False)
    return df.loc[mask].iloc[0] if mask.any() else pd.Series(dtype=object)

# %% [markdown]
# ## Sources et fichiers disponibles
#
# Les fichiers DREES sont en libre accès et téléchargeables sur data.gouv.fr (jeu de données *"La démographie des professionnels de santé depuis 2012"*). Ils doivent être placés dans `data/raw/rpps/`.
#
# | Groupe | Professions | Source DREES | Période |
# |--------|-------------|--------------|---------|
# | RPPS | Médecins | RPPS | 2012–2025 |
# | RPPS | Chirurgiens-dentistes, Pharmaciens, Sages-femmes, Pédicures-podologues | RPPS | 2012–2025 |
# | RPPS | Kinésithérapeutes | RPPS (ADELI avant 2017) | 2017–2024 |
# | ADELI | Orthophonistes, Orthoptistes, Audioprothésistes, Opticiens-lunetiers, Psychologues, Psychomotriciens, Ergothérapeutes, Diététiciens, Manipulateurs ERM, Techniciens de labo, Prof. appareillage | ADELI | 2012–2024 |
# | Autre | Infirmières salariées, Aides-soignantes | BTS | 2013–2021 |
# | Autre | Infirmières libérales | SNDS | 2012–2023 |

# %%
# ── Inventaire des fichiers disponibles ──────────────────────────────────────
print("Vérification des fichiers DREES dans data/raw/rpps/\n")
missing = []
for label, path in ALL_FILES.items():
    if path.exists():
        size = f"{path.stat().st_size / 1e6:.1f} Mo"
        print(f"  \u2713  {label:<35} {size}")
    else:
        print(f"  \u2717  {label:<35} MANQUANT — {path.name}")
        missing.append(label)

if missing:
    print(f"\n{len(missing)} fichier(s) manquant(s). Télécharger depuis :")
    print("  https://www.data.gouv.fr/fr/datasets/la-demographie-des-professionnels-de-sante-depuis-2012")
else:
    print(f"\nTous les fichiers sont présents ({len(ALL_FILES)} fichiers).")
# Out:
# Vérification des fichiers DREES dans data/raw/rpps/
#
#   ✓  Médecins                            71.2 Mo
#   ✓  Chirurgiens-dentistes               14.3 Mo
#   ✓  Pharmaciens                         17.5 Mo
#   ✓  Sages-femmes                        13.6 Mo
#   ✓  Kinésithérapeutes                   13.2 Mo
#   ✓  Pédicures-podologues                4.8 Mo
#   ✓  Orthophonistes                      4.3 Mo
#   ✓  Orthoptistes                        3.2 Mo
#   ✓  Opticiens-lunetiers                 4.1 Mo
#   ✓  Audioprothésistes                   2.7 Mo
#   ✓  Psychologues                        8.7 Mo
#   ✓  Psychomotriciens                    5.0 Mo
#   ✓  Ergothérapeutes                     5.3 Mo
#   ✓  Diététiciens                        4.8 Mo
#   ✓  Manipulateurs ERM                   4.7 Mo
#   ✓  Techniciens de laboratoire          3.8 Mo
#   ✓  Professionnels appareillage         9.5 Mo
#   ✓  Infirmières salariées               0.2 Mo
# ...

# %% [markdown]
# ## Structure des données
#
# Chaque fichier Excel contient un onglet `Effectifs` avec une ligne par combinaison de dimensions :
#
# ```
# territoire | region | departement | [specialites] | [secteur_activite] | exercice | tranche_age | sexe | effectif_2012 | ... | effectif_2025
# ```
#
# La ligne nationale agrégée correspond à : `territoire` contenant "France", et toutes les autres dimensions à valeur `0-Ensemble` ou `00-Ensemble`. C'est cette ligne qui est utilisée pour les totaux par profession.
#
# > Les colonnes `specialites` et `specialites_agregees` sont présentes uniquement dans le fichier Médecins.
# > La colonne `secteur_activite` est présente dans les fichiers autres que Médecins.
# > Les fichiers BTS (infirmières salariées, aides-soignantes) ont des noms de colonnes différents (majuscule, libellé complet).

# %%
# ── Chargement de l'onglet Effectifs pour chaque profession ──────────────────
dfs = {}
for label, path in ALL_FILES.items():
    if path.exists():
        dfs[label] = load_effectifs(path)

print(f"{len(dfs)} fichiers chargés.\n")
for label, df in dfs.items():
    ecols = effectif_cols(df)
    years = f"{ecols[0].split('_')[1]}–{ecols[-1].split('_')[1]}" if ecols else "?"
    print(f"  {label:<35} {df.shape[0]:>6} lignes  {years}")
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[3], line 5
#       3 for label, path in ALL_FILES.items():
#       4     if path.exists():
# ----> 5         dfs[label] = load_effectifs(path)
#       7 print(f"{len(dfs)} fichiers chargés.\n")
#       8 for label, df in dfs.items():
#
# Cell In[1], line 42, in load_effectifs(path, sheet)
#      40 def load_effectifs(path: Path, sheet: str = "Effectifs") -> pd.DataFrame:
#      41     """Load an Effectifs sheet, normalising column names."""
# ---> 42     df = pd.read_excel(path, sheet_name=sheet, header=0)
#      43     df.columns = [str(c).strip() for c in df.columns]
#      44     return df
#
# File c:\Users\rbouazza\Anaconda3\envs\venv_lips\lib\site-packages\pandas\util\_decorators.py:211, in deprecate_kwarg.<locals>._deprecate_kwarg.<locals>.wrapper(*args, **kwargs)
#     209     else:
# ...

# %% [markdown]
# ---
# ## Note méthodologique DREES
#
# La DREES produit chaque année un bilan démographique à partir d'une extraction RPPS au **1er janvier**
# (données en accès restreint, plus complètes que l'open data — incluant notamment l'âge individuel des professionnels).
#
# **Pipeline de traitement DREES :**
# 1. Définition des communes d'activité (code INSEE → code postal → libellé commune en cascade).
# 2. Fusion des tables : activités, coordonnées structures, profil professionnel, diplômes.
# 3. Sélection des activités en cours — exclusion étudiants, SSA, bénévoles.
# 4. Construction de la table par professionnel : les **5 activités les plus récentes** conservées. Moyenne : **1,4 activité/professionnel** en 2025 ; >75 % n'en exercent qu'une.
# 5. Variables synthétiques : mode d'exercice (libéral/salarié/mixte), spécialités médicales.
# 6. Champ : France métropolitaine + DROM uniquement.
#
# > **Important :** les fichiers open data publiés sur data.gouv.fr sont des **statistiques agrégées** — aucun identifiant individuel n'est présent. Pour des données nominatives, utiliser l'annuaire ANS (data.gouv.fr → *Annuaire Santé extraction RPPS*).
#
# ---
# ## Analyses
#
# | # | Question |
# |---|----------|
# | Q1 | Effectifs par profession — dernière année disponible |
# | Q2 | Répartition des médecins par spécialité |
# | Q3 | Libéral vs Salarié par profession |
# | Q4 | Évolution temporelle des effectifs |
# | Q5 | Disparités géographiques par région |

# %% [markdown]
# ---
# ### Q1 — Effectifs par profession (dernière année disponible)
#
# Pour chaque fichier DREES, on extrait la ligne nationale agrégée (`0-Ensemble` pour toutes les dimensions)
# et la valeur de la dernière colonne `effectif_YYYY` disponible.

# %%
# ── Q1 : effectifs par profession ────────────────────────────────────────────
records = []
for label, df in dfs.items():
    ecols = effectif_cols(df)
    if not ecols:
        continue
    last_col = ecols[-1]
    last_year = last_col.split("_")[1]
    row = total_row(df)
    if row.empty or last_col not in row.index:
        continue
    val = row[last_col]
    if pd.notna(val):
        records.append({"profession": label, "effectif": int(val), "annee": last_year})

q1 = pd.DataFrame(records).sort_values("effectif", ascending=False)

print("=== Q1 — Effectifs par profession (dernière année disponible) ===\n")
print(f"  {'Profession':<35} {'Effectif':>10}  {'Année':>6}")
print(f"  {'-'*56}")
for _, r in q1.iterrows():
    print(f"  {r['profession']:<35} {r['effectif']:>10,}  {r['annee']:>6}")
print(f"\n  Total (somme) : {q1['effectif'].sum():,}")

fig, ax = plt.subplots(figsize=(12, 7))
q1_plot = q1.sort_values("effectif")
bars = ax.barh(q1_plot["profession"], q1_plot["effectif"], color="#3498db", alpha=0.85)
for bar, (_, row) in zip(bars, q1_plot.iterrows()):
    ax.text(bar.get_width() * 1.005, bar.get_y() + bar.get_height() / 2,
            f"{row['effectif']/1e3:.0f}k ({row['annee']})", va="center", fontsize=7)
ax.set_xlabel("Nombre de professionnels actifs")
ax.set_title("Q1 — Effectifs par profession de santé (DREES, dernière année disponible)")
plt.tight_layout()
plt.show()

# %% [markdown]
# ---
# ### Q2 — Répartition des médecins par spécialité
#
# Le fichier `Médecins RPPS 2012-2025.xlsx` contient les colonnes `specialites_agregees` et `specialites`
# dans l'onglet `Effectifs`. On filtre sur les lignes où `specialites != "00-Ensemble"` et les dimensions
# géographiques, tranche d'âge, sexe et exercice à `0-Ensemble`/`00-Ensemble` pour obtenir les effectifs
# par spécialité détaillée au niveau national en 2025.

# %%
# ── Q2 : spécialités des médecins ────────────────────────────────────────────
med_df = dfs.get("Médecins")
assert med_df is not None, "Fichier Médecins introuvable — vérifier ALL_FILES"

# Detect columns
spe_col  = next((c for c in med_df.columns if c.lower() == "specialites"), None)
sagg_col = next((c for c in med_df.columns if "specialites_agregees" in c.lower()), None)
reg_col  = next((c for c in med_df.columns if "territoire" in c.lower()), None)
age_col  = next((c for c in med_df.columns if "tranche" in c.lower()), None)
sex_col  = next((c for c in med_df.columns if "sexe" in c.lower()), None)
ex_col   = next((c for c in med_df.columns if "exercice" in c.lower()), None)

assert spe_col, f"Colonne specialites introuvable : {list(med_df.columns)}"

# Filter: France entière, all dims = Ensemble except specialites
mask = (
    med_df[reg_col].astype(str).str.contains("France", na=False)
    & med_df[age_col].astype(str).str.match(r"^0", na=False)
    & med_df[sex_col].astype(str).str.match(r"^0", na=False)
    & med_df[ex_col].astype(str).str.match(r"^0", na=False)
    & ~med_df[spe_col].astype(str).str.match(r"^0", na=False)   # exclude Ensemble
)

spe_df = med_df.loc[mask, [spe_col, "effectif_2025"]].dropna()
spe_df = spe_df.copy()
spe_df["label"] = spe_df[spe_col].astype(str).str.replace(r"^\d+-", "", regex=True)
spe_df = spe_df.sort_values("effectif_2025", ascending=False)

total_med = int(total_row(med_df)["effectif_2025"])
n_mg = int(spe_df[spe_df["label"].str.lower().str.contains("général|general")]["effectif_2025"].sum())
n_spe = total_med - n_mg

print("=== Q2 — Médecins par spécialité (2025) ===\n")
print(f"  Total médecins        : {total_med:,}")
print(f"  Médecine générale     : {n_mg:,}  ({n_mg/total_med*100:.1f}%)")
print(f"  Autres spécialités    : {n_spe:,}  ({n_spe/total_med*100:.1f}%)")
print(f"\n  Top 20 :")
print(f"  {'Spécialité':<55} {'Effectif':>9}  {'%':>6}")
print(f"  {'-'*74}")
for _, r in spe_df.head(20).iterrows():
    n = int(r["effectif_2025"])
    print(f"  {str(r['label'])[:53]:<55} {n:>9,}  {n/total_med*100:>5.1f}%")

fig, axes = plt.subplots(1, 2, figsize=(16, 6))
axes[0].pie([n_mg, n_spe], labels=["Médecine générale", "Spécialistes"],
            autopct="%1.1f%%", colors=["#3498db", "#e74c3c"], startangle=90)
axes[0].set_title("MG vs Spécialistes (2025)", fontweight="bold")

top20 = spe_df.head(20).sort_values("effectif_2025")
axes[1].barh(top20["label"], top20["effectif_2025"], color="#e67e22", alpha=0.85)
axes[1].set_xlabel("Effectifs 2025")
axes[1].set_title("Top 20 spécialités (DREES RPPS)")

plt.suptitle(f"Q2 — Médecins par spécialité — RPPS 2025 ({total_med:,} médecins)",
             fontsize=12, fontweight="bold", y=1.02)
plt.tight_layout()
plt.show()

# %% [markdown]
# ---
# ### Q3 — Libéral vs Salarié par profession
#
# La colonne `exercice` dans chaque fichier DREES distingue `1-Libéral`, `2-Salarié`, `3-Mixte` et `0-Ensemble`.
# On extrait les effectifs pour la dernière année disponible pour les 6 professions RPPS (données les plus complètes)
# et on calcule la part libérale par profession.
#
# La part libérale conditionne directement la visibilité dans Open Medic : un médecin libéral génère des ordonnances
# remboursées (code PSP_SPE par spécialité), un médecin salarié est agrégé sous PSP_SPE = 90.

# %%
# ── Q3 : libéral vs salarié par profession ────────────────────────────────────
MODE_LABELS = {"1": "Libéral", "2": "Salarié", "3": "Mixte"}
records_mode = []

for label, df in {k: v for k, v in dfs.items() if k in RPPS_FILES}.items():
    ex_col = next((c for c in df.columns if "exercice" in c.lower()), None)
    if ex_col is None:
        continue
    ecols = effectif_cols(df)
    last_col = ecols[-1]
    last_year = last_col.split("_")[1]

    # France entière, tranche_age = 0-Ensemble, sexe = 0-Ensemble, all other dims = 0-Ensemble
    base_mask = pd.Series(True, index=df.index)
    for col in df.columns:
        cl = col.lower()
        if "territoire" in cl:
            base_mask &= df[col].astype(str).str.contains("France", na=False)
        elif "tranche" in cl or ("age" in cl and "am_" not in cl):
            base_mask &= df[col].astype(str).str.match(r"^0", na=False)
        elif "sexe" in cl:
            base_mask &= df[col].astype(str).str.match(r"^0", na=False)
        elif "specialite" in cl or "secteur" in cl:
            base_mask &= df[col].astype(str).str.match(r"^0", na=False)

    for mode_code, mode_label in MODE_LABELS.items():
        mask = base_mask & df[ex_col].astype(str).str.startswith(mode_code)
        rows = df.loc[mask, last_col].dropna()
        if rows.empty:
            continue
        records_mode.append({
            "profession": label, "mode": mode_label,
            "effectif": int(rows.iloc[0]), "annee": last_year
        })

q3 = pd.DataFrame(records_mode)
piv = q3.pivot_table(index="profession", columns="mode", values="effectif", fill_value=0)
piv_pct = piv.div(piv.sum(axis=1), axis=0) * 100

print("=== Q3 — Mode d'exercice par profession (%, dernière année RPPS) ===\n")
print(f"  {'Profession':<25} {'Libéral':>9}  {'Salarié':>9}  {'Mixte':>9}")
print(f"  {'-'*57}")
for prof, row in piv_pct.iterrows():
    lib = row.get("Libéral", 0)
    sal = row.get("Salarié", 0)
    mix = row.get("Mixte", 0)
    print(f"  {prof:<25} {lib:>8.1f}%  {sal:>8.1f}%  {mix:>8.1f}%")

fig, axes = plt.subplots(1, 2, figsize=(16, 6))
piv_pct.plot.barh(ax=axes[0], stacked=True, colormap="Set2", alpha=0.9)
axes[0].set_xlabel("% par mode d'exercice")
axes[0].set_title("Part Libéral / Salarié / Mixte par profession")
axes[0].legend(loc="lower right", fontsize=9)

piv["Libéral"].sort_values().plot.barh(ax=axes[1], color="#27ae60", alpha=0.85)
axes[1].set_xlabel("Effectifs libéraux (dernière année disponible)")
axes[1].set_title("Effectifs libéraux par profession")

plt.suptitle("Q3 — Mode d'exercice par profession (DREES RPPS)", fontsize=12, fontweight="bold", y=1.02)
plt.tight_layout()
plt.show()

# %% [markdown]
# ---
# ### Q4 — Évolution temporelle des effectifs
#
# Les colonnes `effectif_YYYY` permettent de suivre l'évolution des effectifs depuis 2012.
# On trace l'évolution pour les 6 professions RPPS (séries complètes depuis 2012 ou année de bascule)
# ainsi que le total toutes professions RPPS confondues.

# %%
# ── Q4 : évolution temporelle ────────────────────────────────────────────────
series = {}
for label, df in {k: v for k, v in dfs.items() if k in RPPS_FILES}.items():
    row = total_row(df)
    if row.empty:
        continue
    ecols = effectif_cols(df)
    s = pd.Series(
        {int(c.split("_")[1]): row[c] for c in ecols if pd.notna(row.get(c))},
        name=label
    )
    series[label] = s

evol = pd.DataFrame(series).sort_index()

print("=== Q4 — Évolution des effectifs RPPS par profession ===\n")
print(evol.to_string())

fig, axes = plt.subplots(1, 2, figsize=(16, 6))

for label, s in series.items():
    axes[0].plot(s.index, s.values / 1e3, marker="o", markersize=3, label=label)
axes[0].set_xlabel("Année")
axes[0].set_ylabel("Effectifs (milliers)")
axes[0].set_title("Évolution par profession (RPPS)")
axes[0].legend(fontsize=8)
axes[0].grid(alpha=0.3)

# Index 100 = première année disponible par profession
for label, s in series.items():
    s_idx = s / s.iloc[0] * 100
    axes[1].plot(s_idx.index, s_idx.values, marker="o", markersize=3, label=label)
axes[1].axhline(100, color="gray", linestyle="--", linewidth=0.8)
axes[1].set_xlabel("Année")
axes[1].set_ylabel("Indice base 100 (première année disponible)")
axes[1].set_title("Évolution relative par profession (base 100)")
axes[1].legend(fontsize=8)
axes[1].grid(alpha=0.3)

plt.suptitle("Q4 — Évolution temporelle des effectifs (DREES RPPS)", fontsize=12, fontweight="bold", y=1.02)
plt.tight_layout()
plt.show()

# %% [markdown]
# ---
# ### Q5 — Disparités géographiques par région
#
# La colonne `region` contient le code et le libellé de la région (ex. `11-Île-de-France`).
# On filtre sur le niveau région (exclut France entière et les lignes départementales) pour les médecins
# libéraux en 2025 et on visualise les disparités d'effectifs entre régions.
#
# > Pour calculer des densités pour 100 000 habitants sans croisement externe, utiliser directement
# > la colonne `densite_2025` de l'onglet `Densités`.

# %%
# ── Q5 : disparités géographiques par région ─────────────────────────────────
med_df = dfs.get("Médecins")
assert med_df is not None

reg_col  = next(c for c in med_df.columns if "region" in c.lower() and "dep" not in c.lower())
dept_col = next(c for c in med_df.columns if "departement" in c.lower())
terr_col = next(c for c in med_df.columns if "territoire" in c.lower())
ex_col   = next(c for c in med_df.columns if "exercice" in c.lower())
age_col  = next(c for c in med_df.columns if "tranche" in c.lower())
sex_col  = next(c for c in med_df.columns if "sexe" in c.lower())
spe_col  = next((c for c in med_df.columns if c.lower() == "specialites"), None)
sagg_col = next((c for c in med_df.columns if "specialites_agregees" in c.lower()), None)

# Filter: region level (not France entière, not département), libéral, all Ensemble dims
mask = (
    ~med_df[terr_col].astype(str).str.contains("France", na=False)
    & med_df[dept_col].astype(str).str.match(r"^0", na=False)   # dept = 000-Ensemble → région level
    & med_df[ex_col].astype(str).str.startswith("1")            # Libéral
    & med_df[age_col].astype(str).str.match(r"^0", na=False)
    & med_df[sex_col].astype(str).str.match(r"^0", na=False)
)
if spe_col:
    mask &= med_df[spe_col].astype(str).str.match(r"^0", na=False)
if sagg_col:
    mask &= med_df[sagg_col].astype(str).str.match(r"^0", na=False)

geo_df = med_df.loc[mask, [reg_col, "effectif_2025"]].dropna().copy()
geo_df["region_label"] = geo_df[reg_col].astype(str).str.replace(r"^\d+-", "", regex=True)
geo_df = geo_df.sort_values("effectif_2025", ascending=False)

print("=== Q5 — Médecins libéraux par région (2025) ===\n")
print(f"  {'Région':<35} {'Effectifs':>10}")
print(f"  {'-'*47}")
for _, r in geo_df.iterrows():
    print(f"  {str(r['region_label']):<35} {int(r['effectif_2025']):>10,}")

# Also load densités sheet for density-based view
dens_df = load_effectifs(RPPS_FILES["Médecins"], sheet="Densités")
dens_reg_col  = next((c for c in dens_df.columns if "region" in c.lower() and "dep" not in c.lower()), None)
dens_dept_col = next((c for c in dens_df.columns if "departement" in c.lower()), None)
dens_terr_col = next((c for c in dens_df.columns if "territoire" in c.lower()), None)
dens_ex_col   = next((c for c in dens_df.columns if "exercice" in c.lower()), None)
dens_age_col  = next((c for c in dens_df.columns if "tranche" in c.lower()), None)
dens_sex_col  = next((c for c in dens_df.columns if "sexe" in c.lower()), None)
dens_spe_col  = next((c for c in dens_df.columns if c.lower() == "specialites"), None)
dens_sagg_col = next((c for c in dens_df.columns if "specialites_agregees" in c.lower()), None)
dens_col      = next((c for c in dens_df.columns if c.startswith("densite_")), None)  # use first year for now
dens_cols_all = sorted(c for c in dens_df.columns if c.startswith("densite_"))
dens_col      = dens_cols_all[-1] if dens_cols_all else None

dens_mask = (
    ~dens_df[dens_terr_col].astype(str).str.contains("France", na=False)
    & dens_df[dens_dept_col].astype(str).str.match(r"^0", na=False)
    & dens_df[dens_ex_col].astype(str).str.startswith("1")
    & dens_df[dens_age_col].astype(str).str.match(r"^0", na=False)
    & dens_df[dens_sex_col].astype(str).str.match(r"^0", na=False)
)
if dens_spe_col:
    dens_mask &= dens_df[dens_spe_col].astype(str).str.match(r"^0", na=False)
if dens_sagg_col:
    dens_mask &= dens_df[dens_sagg_col].astype(str).str.match(r"^0", na=False)

dens_geo = dens_df.loc[dens_mask, [dens_reg_col, dens_col]].dropna().copy()
dens_geo["region_label"] = dens_geo[dens_reg_col].astype(str).str.replace(r"^\d+-", "", regex=True)
dens_geo = dens_geo.sort_values(dens_col, ascending=False)

fig, axes = plt.subplots(1, 2, figsize=(16, 8))

geo_sorted = geo_df.sort_values("effectif_2025")
axes[0].barh(geo_sorted["region_label"], geo_sorted["effectif_2025"], color="#3498db", alpha=0.85)
axes[0].set_xlabel("Effectifs libéraux 2025")
axes[0].set_title("Médecins libéraux — effectifs par région")

dens_sorted = dens_geo.sort_values(dens_col)
axes[1].barh(dens_sorted["region_label"], dens_sorted[dens_col], color="#e74c3c", alpha=0.85)
axes[1].set_xlabel(f"Densité pour 100 000 hab. ({dens_col.split('_')[1]})")
axes[1].set_title("Médecins libéraux — densité par région")

plt.suptitle("Q5 — Disparités géographiques — Médecins libéraux (DREES RPPS)",
             fontsize=12, fontweight="bold", y=1.02)
plt.tight_layout()
plt.show()
